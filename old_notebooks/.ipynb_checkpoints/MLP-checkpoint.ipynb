# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
#dataset
input_path = r"C:\Users\giova\OneDrive\Desktop\ZEULI\3 Zeuli 220623\3 Zeuli 220623 ground truth.xlsx"

#alberi selezionati per far parte del test set
alberi_test_set = [147, 146, 60, 59, 141, 142, 36, 37]

df = pd.read_excel(input_path)
df
# Out:
#        ID_Pixel  ID_Albero     UTM_lon       UTM_lat    Red  Green   Blue  \
# 0           0_0        148  599776.152  4.565502e+06  10196  18429  13797
# 1           0_1        148  599776.232  4.565502e+06   9850  18950  13862
# 2           0_2        148  599776.312  4.565502e+06   9384  19911  14077
# 3           0_3        148  599776.392  4.565502e+06   9907  19974  13715
# 4           0_4        148  599776.472  4.565502e+06  10355  20118  13217
# ...         ...        ...         ...           ...    ...    ...    ...
# 120093    90_39         59  599810.792  4.565672e+06  20656  35759  28383
# 120094    90_40         59  599810.872  4.565672e+06  24906  34403  28565
# 120095    91_38         59  599810.712  4.565672e+06  24335  35603  32737
# 120096    91_39         59  599810.792  4.565672e+06  22815  35183  30407
# 120097    91_40         59  599810.872  4.565672e+06  25972  35260  29847
#
#           NIR  Rededge      NDVI     OSAVI         TCARI     TCARIOSAVI  \
# ...

# %%
#estrazione del test set
df_test = df[df['ID_Albero'].isin(alberi_test_set)]
print(f"Valori unici ID_Albero in df_test = {df_test['ID_Albero'].unique()}")
df_test
# Out:
# Valori unici ID_Albero in df_test = [141 142  37  36 147 146  60  59]
#        ID_Pixel  ID_Albero     UTM_lon       UTM_lat    Red  Green   Blue  \
# 5096      16_29        141  599818.072  4.565721e+06  15466  24169  19455
# 5097      16_31        141  599818.232  4.565721e+06  17761  22861  18666
# 5098      16_32        141  599818.312  4.565721e+06  17562  25010  20422
# 5099      17_28        141  599817.992  4.565721e+06  16311  27786  22979
# 5100      17_29        141  599818.072  4.565721e+06  15974  29479  22579
# ...         ...        ...         ...           ...    ...    ...    ...
# 120093    90_39         59  599810.792  4.565672e+06  20656  35759  28383
# 120094    90_40         59  599810.872  4.565672e+06  24906  34403  28565
# 120095    91_38         59  599810.712  4.565672e+06  24335  35603  32737
# 120096    91_39         59  599810.792  4.565672e+06  22815  35183  30407
# 120097    91_40         59  599810.872  4.565672e+06  25972  35260  29847
#
# ...

# %%
#estrazione del training test
df_train = df.drop(df_test.index)
df_train
# Out:
#        ID_Pixel  ID_Albero     UTM_lon       UTM_lat    Red  Green   Blue  \
# 0           0_0        148  599776.152  4.565502e+06  10196  18429  13797
# 1           0_1        148  599776.232  4.565502e+06   9850  18950  13862
# 2           0_2        148  599776.312  4.565502e+06   9384  19911  14077
# 3           0_3        148  599776.392  4.565502e+06   9907  19974  13715
# 4           0_4        148  599776.472  4.565502e+06  10355  20118  13217
# ...         ...        ...         ...           ...    ...    ...    ...
# 107187    97_11         53  599749.752  4.565533e+06  18272  18006  14512
# 107188    97_12         53  599749.832  4.565533e+06  20217  19524  14589
# 107189    97_17         53  599750.232  4.565533e+06  18608  19243  17495
# 107190    97_18         53  599750.312  4.565533e+06  19298  19337  17386
# 107191    97_19         53  599750.392  4.565533e+06  21628  19909  17485
#
#           NIR  Rededge      NDVI     OSAVI         TCARI    TCARIOSAVI  \
# ...

# %%
#check se training set e test set hanno record in comune
df_common = df_train.isin(df_test)
df_common['ID_Pixel'].unique()
# Out:
# array([False])

# %%
scaler = StandardScaler()
features = df_train.drop(['ID_Pixel', 'ID_Albero', 'UTM_lon', 'UTM_lat','NDVI', 'OSAVI', 
                          'TCARI', 'TCARIOSAVI', 'EVI', 'MCARI', 'MCARIOSAVI', 'SR',
                          'TVI', 'NDRE', 'SWP'], axis=1).columns.to_list()

#standartizzazione features del training set
train_df2 = df_train[features]
X_train = pd.DataFrame(scaler.fit_transform(train_df2[features]),
                                  columns=features,
                                  index=train_df2.index)

#standartizzazione features del test set
test_df2 = df_test[features]
X_test = pd.DataFrame(scaler.fit_transform(test_df2[features]),
                                  columns=features,
                                  index=test_df2.index)
X_train.describe()
# Out:
#                 Red         Green          Blue           NIR       Rededge
# count  8.788300e+04  8.788300e+04  8.788300e+04  8.788300e+04  8.788300e+04
# mean  -1.623488e-16  1.820764e-16 -9.314034e-17  3.182295e-16  1.170722e-16
# std    1.000006e+00  1.000006e+00  1.000006e+00  1.000006e+00  1.000006e+00
# min   -1.984744e+00 -2.827774e+00 -2.429495e+00 -2.931400e+00 -2.385871e+00
# 25%   -6.835721e-01 -7.167528e-01 -6.762146e-01 -6.630700e-01 -7.193218e-01
# 50%   -2.689924e-01 -1.598891e-01 -2.180509e-01  1.897798e-01 -2.336446e-01
# 75%    3.941437e-01  5.833501e-01  4.117773e-01  7.785583e-01  5.073870e-01
# max    4.507714e+00  7.801801e+00  1.153545e+01  2.269890e+00  5.036798e+00

# %%
X_test.describe()
# Out:
#                 Red         Green          Blue           NIR       Rededge
# count  3.221500e+04  3.221500e+04  3.221500e+04  3.221500e+04  3.221500e+04
# mean   8.469608e-17  1.835082e-16  2.823203e-17  3.317263e-16  2.470302e-16
# std    1.000016e+00  1.000016e+00  1.000016e+00  1.000016e+00  1.000016e+00
# min   -1.766912e+00 -1.935750e+00 -1.921052e+00 -3.235779e+00 -2.062795e+00
# 25%   -8.122158e-01 -9.304501e-01 -9.166108e-01 -4.869293e-01 -8.969906e-01
# 50%   -9.098153e-02 -4.333557e-02 -2.334347e-02  2.347364e-01 -5.208186e-02
# 75%    5.991245e-01  7.650295e-01  7.235527e-01  7.071701e-01  7.510932e-01
# max    4.050039e+00  3.595521e+00  5.121821e+00  2.053314e+00  3.402804e+00

# %%
y_train = df_train['SWP']
y_test = df_test['SWP']

print(f"y_train = {y_train}")
print(f"y_test = {y_test}")
# Out:
# y_train = 0         33.6
# 1         33.6
# 2         33.6
# 3         33.6
# 4         33.6
#           ...
# 107187    34.6
# 107188    34.6
# 107189    34.6
# 107190    34.6
# 107191    34.6
# Name: SWP, Length: 87883, dtype: float64
# y_test = 5096      28.2
# 5097      28.2
# 5098      28.2
# 5099      28.2
# 5100      28.2
#           ...
# 120093    32.4
# 120094    32.4
# 120095    32.4
# 120096    32.4
# 120097    32.4
# Name: SWP, Length: 32215, dtype: float64

# %%
class MLP(nn.Module):
  '''
    Multilayer Perceptron.
  '''
  def __init__(self, input_size, hidden_size, output_size):
    super().__init__()
    self.layers = nn.Sequential(
      nn.Linear(input_size, hidden_size),
      nn.ReLU(),
      nn.Linear(hidden_size, output_size),
    )


  def forward(self, x):
    '''Forward pass'''
    return self.layers(x)

# %%
torch.manual_seed(42)

# iperparametri
input_size = X_train.shape[1]  # Numero di features
hidden_size = 64
output_size = 1 
learning_rate = 1e-4
num_epochs = 20



#Conversione X_train e y_train in tensori pytorch
X_train_tensor = torch.tensor(X_train.values, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.float32)

mlp = MLP(input_size, hidden_size, output_size)
loss_function = nn.MSELoss()
optimizer = optim.Adam(mlp.parameters(), lr=learning_rate)

train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=1)

for epoch in range(num_epochs):
    current_loss = 0.0

    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = mlp(inputs)
        loss = loss_function(outputs, targets)
        loss.backward()
        optimizer.step()

        current_loss += loss.item()

    print('Loss dopo epoca %d: %.3f' % (epoch+1, current_loss / len(train_loader)))

print('Training terminato')
# Out:
# Loss dopo epoca 1: 619.279
# Loss dopo epoca 2: 373.704
# Loss dopo epoca 3: 209.331
# Loss dopo epoca 4: 159.876
# Loss dopo epoca 5: 130.694
# Loss dopo epoca 6: 112.899
# Loss dopo epoca 7: 103.947
# Loss dopo epoca 8: 99.930
# Loss dopo epoca 9: 98.184
# Loss dopo epoca 10: 97.359
# Loss dopo epoca 11: 96.962
# Loss dopo epoca 12: 96.769
# Loss dopo epoca 13: 96.667
# Loss dopo epoca 14: 96.602
# Loss dopo epoca 15: 96.579
# Loss dopo epoca 16: 96.535
# Loss dopo epoca 17: 96.531
# Loss dopo epoca 18: 96.491
# Loss dopo epoca 19: 96.495
# Loss dopo epoca 20: 96.502
# Training terminato

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# C:\Users\giova\anaconda3\envs\deep_learning_env\lib\site-packages\tensorflow\python\framework\dtypes.py:513: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.object,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#
# File ~\anaconda3\envs\deep_learning_env\lib\site-packages\tensorflow\__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\anaconda3\envs\deep_learning_env\lib\site-packages\tensorflow\python\__init__.py:45
# ...

# %%
# !conda install numpy --update-deps
# Out:
# ...
# Solving environment: ...working... Solving environment: ...working...
#
# Updating numpy-base is constricted by
#
# numpy -> requires numpy-base==1.24.3=py38h8a87ada_1
#
# If you are sure you want an update of your package either try `conda update --all` or install a specific version of the package you want using `conda install <pkg>=<version>`
#
# done
# done
#
# # All requested packages already installed.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.1.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.1.2
