# %%
from osgeo import gdal
import sentinelhub as sh
from sentinelhub import CRS
import rasterio
import pandas as pd
import matplotlib.pyplot as plt

# %%
input_folder = r"C:\Users\giova\OneDrive\Desktop\ZEULI"
input_path = input_folder + "\\UNICO_ZEULI_OLIVO.xlsx"
output_path = input_folder + "\\ZEULI_OLIVO_UTM_220623"

# %%
#Apre foglio excel in un dataframe
df = pd.read_excel(input_path, header=1)
#print(df)
df_day = df[df["DATA  RILIEVO"] == "2022-06-23"]
#print(df[["LONGITUDINE", "LATITUDINE"]])
print(df_day[["LONGITUDINE", "LATITUDINE", "ID"]])
# Out:
#      LONGITUDINE  LATITUDINE   ID
# 90     16.198634   41.240265   31
# 91     16.198712   41.240348   32
# 92     16.198625   41.240438   33
# 93     16.198615   41.240596   34
# 94     16.198690   41.240753   35
# 95     16.192928   41.239752   36
# 96     16.192811   41.239655   37
# 97     16.192678   41.240116   41
# 98     16.192963   41.240181   42
# 99     16.192775   41.240217   43
# 100    16.192894   41.240327   44
# 101    16.192770   41.240511   45
# 102    16.192884   41.240607   46
# 103    16.190536   41.234991   51
# 104    16.190393   41.234906   52
# 105    16.190311   41.235081   53
# 106    16.190821   41.234821   54
# 107    16.191038   41.236320   59
# 108    16.191030   41.236224   60
# 109    16.198782   41.240512  136
# 110    16.198884   41.240593  137
# 111    16.191125   41.236701  141
# 112    16.191120   41.236809  142
# 113    16.192651   41.240313  145
# 114    16.191164   41.236120  146
# 115    16.190921   41.236020  147
# ...

# %%
#CRS delle immagini
target_crs = CRS.UTM_33N
print(target_crs)

#CRS standard lon/lat
source_crs = CRS.WGS84

#Apertura tif e calcolo matrice affine
#ds = gdal.Open("3 Zeuli 220623 ORTHO_MULTI.tif")
#gt = ds.GetGeoTransform()
# Out:
# EPSG:32633

# %%
# info raster
n_bands = ds.RasterCount
image_width = ds.RasterXSize
image_height = ds.RasterYSize

print(n_bands)
print(image_width)
print(image_height)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # info raster
# ----> 2 n_bands = ds.RasterCount
#       3 image_width = ds.RasterXSize
#       4 image_height = ds.RasterYSize
#
# AttributeError: 'NoneType' object has no attribute 'RasterCount'

# %%
# calcolo target_crs con il modulo di sentinelhub
# c'è un mismatch su tormaresca, usare quello inserito a mano
# (zeuli ok)

#target_crs = sh.get_utm_crs(lon, lat, source_crs)
#target_crs

# %%
# conversione punti da lon/lat in source_crs a UTM in target_crs
utm_coords = []
for lon, lat, id in zip(df_day['LONGITUDINE'], df_day['LATITUDINE'], df_day['ID']):
    east, north = sh.transform_point((lon, lat), source_crs, target_crs)
    utm_coords.append((east,north,id))

utm_coords
utm_df = pd.DataFrame(utm_coords, columns = ['UTM_lon', 'UTM_lat', 'ID'])
utm_df
# Out:
#           UTM_lon       UTM_lat   ID
# 0   600440.974716  4.566122e+06   31
# 1   600447.383844  4.566131e+06   32
# 2   600439.955630  4.566141e+06   33
# 3   600438.875718  4.566159e+06   34
# 4   600444.920103  4.566176e+06   35
# 5   599963.606182  4.566058e+06   36
# 6   599953.949571  4.566048e+06   37
# 7   599942.101965  4.566099e+06   41
# 8   599965.885333  4.566106e+06   42
# 9   599950.076470  4.566110e+06   43
# 10  599959.880785  4.566122e+06   44
# 11  599949.209494  4.566143e+06   45
# 12  599958.616112  4.566153e+06   46
# 13  599770.400901  4.565527e+06   51
# 14  599758.546101  4.565518e+06   52
# 15  599751.408040  4.565537e+06   53
# 16  599794.543781  4.565509e+06   54
# 17  599810.448826  4.565675e+06   59
# 18  599809.924459  4.565665e+06   60
# 19  600452.998526  4.566150e+06  136
# 20  600461.421814  4.566159e+06  137
# 21  599817.159964  4.565718e+06  141
# 22  599816.576625  4.565730e+06  142
# 23  599939.539269  4.566120e+06  145
# ...

# %%
df_day = pd.merge(df_day, utm_df, on='ID')
df_day
# Out:
#    DATA  RILIEVO   ID  CLUSTER       Long DSM        Lat DSM  LONGITUDINE  \
# 0     2022-06-23   31        0  16° 11'55.08"  41° 14'24.95"    16.198634
# 1     2022-06-23   32        0  16° 11'55.36"  41° 14'25.25"    16.198712
# 2     2022-06-23   33        0  16° 11'55.04"  41° 14'25.57"    16.198625
# 3     2022-06-23   34        0  16° 11'55.01"  41° 14'26.14"    16.198615
# 4     2022-06-23   35        0  16° 11'55.28"  41° 14'26.71"    16.198690
# 5     2022-06-23   36        0  16° 11'34.53"  41° 14'23.10"    16.192928
# 6     2022-06-23   37        0  16° 11'34.11"  41° 14'22.75"    16.192811
# 7     2022-06-23   41        1  16° 11'33.63"  41° 14'24.41"    16.192678
# 8     2022-06-23   42        1  16° 11'34.66"  41° 14'24.65"    16.192963
# 9     2022-06-23   43        1  16° 11'33.99"  41° 14'24.78"    16.192775
# 10    2022-06-23   44        1  16° 11'34.41"  41° 14'25.17"    16.192894
# 11    2022-06-23   45        1  16° 11'33.97"  41° 14'25.83"    16.192770
# ...

# %%
# Seleziona solo le colonne desiderate nell'ordine specificato
df_new = df_day[['DATA  RILIEVO', 'ID', 'LONGITUDINE', 'LATITUDINE', 'UTM_lon', 'UTM_lat', 'SWP']]

df_new['SWP'] = pd.to_numeric(df_new['SWP'], errors='coerce')
df_new = df_new.dropna(subset=['SWP'])

df_new['DATA  RILIEVO'] = pd.to_datetime(df_new['DATA  RILIEVO'])
df_new['DATA  RILIEVO'] = df_new['DATA  RILIEVO'].dt.date

# Stampa del nuovo DataFrame
print(df_new)
# Out:
#    DATA  RILIEVO   ID  LONGITUDINE  LATITUDINE        UTM_lon       UTM_lat  \
# 1     2022-06-23   32    16.198712   41.240348  600447.383844  4.566131e+06
# 2     2022-06-23   33    16.198625   41.240438  600439.955630  4.566141e+06
# 3     2022-06-23   34    16.198615   41.240596  600438.875718  4.566159e+06
# 4     2022-06-23   35    16.198690   41.240753  600444.920103  4.566176e+06
# 5     2022-06-23   36    16.192928   41.239752  599963.606182  4.566058e+06
# 6     2022-06-23   37    16.192811   41.239655  599953.949571  4.566048e+06
# 7     2022-06-23   41    16.192678   41.240116  599942.101965  4.566099e+06
# 8     2022-06-23   42    16.192963   41.240181  599965.885333  4.566106e+06
# 9     2022-06-23   43    16.192775   41.240217  599950.076470  4.566110e+06
# 10    2022-06-23   44    16.192894   41.240327  599959.880785  4.566122e+06
# 11    2022-06-23   45    16.192770   41.240511  599949.209494  4.566143e+06
# ...

# %%
df_new.to_excel(output_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File ~\anaconda3\envs\deep_learning_env\lib\site-packages\pandas\io\excel\_base.py:1111, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1110 try:
# -> 1111     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1112     if engine == "auto":
#
# File ~\anaconda3\envs\deep_learning_env\lib\site-packages\pandas\_config\config.py:261, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     260 def __call__(self, *args, **kwds) -> T:
# --> 261     return self.__func__(*args, **kwds)
#
# File ~\anaconda3\envs\deep_learning_env\lib\site-packages\pandas\_config\config.py:135, in _get_option(pat, silent)
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
# ...

# %%
# Coordinate dei quattro angoli dell'immagine in pixel
top_left = (0, 0)
top_right = (0, image_width - 1)
bottom_left = (image_height - 1, 0)
bottom_right = (image_height - 1, image_width - 1)

# Trasforma le coordinate da pixel a UTM
utm_top_left = sh.pixel_to_utm(top_left[1], top_left[0], gt)
utm_top_right = sh.pixel_to_utm(top_right[1], top_right[0], gt)
utm_bottom_left = sh.pixel_to_utm(bottom_left[1], bottom_left[0], gt)
utm_bottom_right = sh.pixel_to_utm(bottom_right[1], bottom_right[0], gt)

print("Coordinate UTM Top Left:", utm_top_left)
print("Coordinate UTM Top Right:", utm_top_right)
print("Coordinate UTM Bottom Left:", utm_bottom_left)
print("Coordinate UTM Bottom Right:", utm_bottom_right)
# Out:
# Coordinate UTM Top Left: (599595.552118027, 4566301.340055789)
# Coordinate UTM Top Right: (599595.552118027, 4565302.540055789)
# Coordinate UTM Bottom Left: (600565.792118027, 4566301.340055789)
# Coordinate UTM Bottom Right: (600565.792118027, 4565302.540055789)

# %%
#Per trovare le coordinate row,col nella matrice immagine
row, col = sh.utm_to_pixel(east=east, north=north, transform=gt)
print(row, col)
# Out:
# 10070 2301

# %%
#Per accedere al valore del pixel

#Legge la prima banda
band = ds.GetRasterBand(1)
#Crea un array con l'immagine
image = band.ReadAsArray(0, 0, image_width, image_height)

#Params:
#   col = coordinata colonna (cast a int perchè potrebbe capitare sia un float)
#   row = coordinata riga
#   9, 9 = mostra i valori dei pixel in una finestra 9x9. il pixel individuato da
#          (col, row) è quello in alto a sinistra
#band.ReadAsArray(int(col), int(row), 9, 9)

# %%
# Plot immagine
plt.figure(figsize=(10, 10))
plt.imshow(image, cmap='gray', extent=(gt[0], gt[0] + ds.RasterXSize * gt[1],    
                                       gt[3] + ds.RasterYSize * gt[5], gt[3]), origin='upper')
#Plot punti geolocalizzati
for (east, north) in utm_coords:
    plt.plot(east, north, 'ro', markersize=2)

# Plot limiti raster (una porzione di immagine è fuori)
plt.plot([utm_top_left[0], utm_top_right[0], utm_bottom_right[0], utm_bottom_left[0], utm_top_left[0]],
         [utm_top_left[1], utm_top_right[1], utm_bottom_right[1], utm_bottom_left[1], utm_top_left[1]], 'g--', label='Limiti Raster')

# Labels
plt.xlabel('East (UTM)')
plt.ylabel('North (UTM)')

plt.legend()
plt.show()
