# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from math import sqrt
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
dataset = pd.read_csv(r"C:\Users\giova\OneDrive\Desktop\ZEULI\dataset\Pixel_wise\dataset_pixel_wise.csv")
X = dataset[['Blue-444', 'Blue', 'Green-531', 'Green', 'NIR', 'Red-650',
       'Rededge-705', 'Rededge-740', 'Rededge', 'Red', 'Temp',
       'TEMP ARIA', 'UMID ARIA', 'ID_Albero', 'SWP']]
y = dataset['SWP']

# %%
X
# Out:
#         Blue-444   Blue  Green-531  Green    NIR  Red-650  Rededge-705  \
# 0          26318  14458      17481  21727  19144    15119        13345
# 1          23649  11795      16503  17183  18285    11264        11011
# 2          24917  13890      13710  20420  18263    13593        11307
# 3          27213  17539      11323  22778  17483    17574        11457
# 4          22200  11545      13117  14558  16985    10849        13065
# ...          ...    ...        ...    ...    ...      ...          ...
# 254670     33148  27853      28475  32842  42214    33826        26752
# 254671     32787  22670      28103  34071  40815    30858        25174
# 254672     33878  31633      33180  32877  44458    34083        32586
# 254673     35361  29500      30419  33282  42663    34321        29290
# 254674     33050  24579      30883  35140  39372    32124        28374
#
#         Rededge-740  Rededge    Red       Temp  TEMP ARIA  UMID ARIA  \
# ...

# %%
d = X.groupby(by=['ID_Albero', 'SWP'])
for x, y in d:
    print(f'{x}\n{y}\n')
# Out:
# (32, 8.8)
#        Blue-444   Blue  Green-531  Green    NIR  Red-650  Rededge-705  \
# 33723     12411  10266      11318  10850  17058    10890        13044
# 33724     12803   9847      11715  11199  17672    10620        14398
# 33725     13744  10186      11331  12102  15527    10750        15133
# 33726     12632  12002      16654  11767  21413    12439        21761
# 33727     12219  10934      15028  11169  20065    11392        19550
# ...         ...    ...        ...    ...    ...      ...          ...
# 40195     18689  20078      21034  22528  33528    22342        26866
# 40196     19331  19021      25912  23172  29084    19890        28277
# 40197     20298  21419      23827  23964  30985    22766        27017
# 40198     21911  22695      25115  24493  29749    21768        26654
# 40199     22846  23183      25127  25185  28686    21782        26520
#
#        Rededge-740  Rededge    Red       Temp  TEMP ARIA  UMID ARIA  \
# ...
